# %%
import sys
import os
import random

sys.path.append(os.path.abspath("../src"))

from technology_diffusion import *

# %%
N = 1000
K = 50

delta = 0.5
xi = 0.1
d = 2
max_time = 60
buffer_dim = 5000
verbose = 0

random.seed(42)
for i in range(10):

    print(f'\n\n--- Instance {i} ---')
    g, thetas = create_pa_graph(n_nodes=N, c=1, seed= i, init_nodes=3, init_mode="complete")  

    x0 = high_thetas_start(g, N, K, thetas = thetas, connected = 1)
    s0 = connected_component_spread(g, x0, thetas=thetas, max_t=1000)[0]
    print(f'Initial spread: {s0}')
    s, x, history = Neighbor_Search(g, thetas, x0, delta, xi, d, max_time, buffer_dim, verbose = verbose)
    print(f'NS spread: {s[-1]}')
    s, x, history = NS_marta(g, x0, thetas, max_time=max_time, H_RADIUS=10)
    print(f'NS_marta spread: {s[-1]}')
    s, x, history = NS_matteo(g, thetas, x0, delta, xi, d, max_time, buffer_dim, verbose=0, min_conn=20, mg_max_depth=10)
    print(f'NS_matteo spread: {s[-1]}')
# Out:
# --- Instance 0 ---
# Initial spread: 87
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 20
#      18 s0 = connected_component_spread(g, x0, thetas=thetas, max_t=1000)[0]
#      19 print(f'Initial spread: {s0}')
# ---> 20 s, x, history = Neighbor_Search(g, thetas, x0, delta, xi, d, max_time, buffer_dim, verbose = verbose)
#      21 print(f'NS spread: {s[-1]}')
#      22 s, x, history = NS_last(g, x0, thetas, max_time=max_time, H_RADIUS=10)
#
# File ~/Desktop/td_git/src/technology_diffusion/ns.py:89, in Neighbor_Search(g, thetas, x0, delta, xi, d, max_time, buffer_dim, verbose)
#      86         temp.remove(elem1)
#      87         neighbors.append(temp)
# ---> 89 found_opt, x_temp, s_temp = evaluate_neighbors(neighbors, s_hist[-1], x_hist[-1])
#      90 if found_opt:
#      91     x_hist.append(x_temp)
#
# File ~/Desktop/td_git/src/technology_diffusion/ns.py:52, in Neighbor_Search.<locals>.evaluate_neighbors(neighbors, s_base, x_base)
#      49     stop = True
#      50     break
# ---> 52 s_elem = connected_component_spread(g, x_elem, thetas=thetas, max_t=1000)[0]
#      53 buffer.append(key)
#      54 calls += 1
#
# File ~/Desktop/td_git/src/technology_diffusion/helpers.py:166, in connected_component_spread(g, x0, thetas, max_t)
#     164 for _ in range(max_t):
#     165     prev = active.copy()
# --> 166     new = connected_component_update(g, prev, thetas)
#     167     active = prev | new
#     168     if np.array_equal(active, prev):
#
# File ~/Desktop/td_git/src/technology_diffusion/helpers.py:142, in connected_component_update(g, active_mask, thetas)
#     140 for u in g.neighbors(v):
#     141     if active_mask[u]:
# --> 142         c = comp_id_of.get(u)
#     143         if c is not None:
#     144             touched.add(c)
#
# KeyboardInterrupt:
